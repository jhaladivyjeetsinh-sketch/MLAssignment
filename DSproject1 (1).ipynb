# %% [raw]
# Linear Regression

# %% [raw]
# 1. Salary Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\USER\Downloads\Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
x = df[['YearsExperience']]
y = df['Salary']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =42)

# %%
x_train
# Out:
#     YearsExperience
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0

# %%
x_test
# Out:
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7

# %%
y_train
# Out:
# 28    122391
# 24    109431
# 12     56957
# 0      39343
# 4      39891
# 16     66029
# 5      56642
# 13     57081
# 11     55794
# 22    101302
# 1      46205
# 2      37731
# 25    105582
# 3      43525
# 21     98273
# 26    116969
# 18     81363
# 29    121872
# 20     91738
# 7      54445
# 10     63218
# 14     61111
# 19     93940
# 6      60150
# Name: Salary, dtype: int64

# %%
y_test
# Out:
# 27    112635
# 15     67938
# 23    113812
# 17     83088
# 8      64445
# 9      57189
# Name: Salary, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample = [[5]]

# %%
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Predicted Salary =", prediction)
# Out:
# Predicted Salary = [72440.65962693]

# %%
import seaborn as sns
import matplotlid.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[68], line 2
#       1 import seaborn as sns
# ----> 2 import matplotlid.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlid'

# %%
sns.heatmap(df.corr(),annot = True,cmap = 'viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 sns.heatmap(df.corr(),annot = True,cmap = 'viridis')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [raw]
# 2. California Housing

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df1 = pd.read_csv(r"C:\Users\USER\Downloads\housing.csv")

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
df1.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df1.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df1.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df1 = df1.drop(columns = ['total_bedrooms'])

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                  41          880         322
# 1        -122.22     37.86                  21         7099        2401
# 2        -122.24     37.85                  52         1467         496
# 3        -122.25     37.85                  52         1274         558
# 4        -122.25     37.85                  52         1627         565
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                  25         1665         845
# 20636    -121.21     39.49                  18          697         356
# 20637    -121.22     39.43                  17         2254        1007
# 20638    -121.32     39.43                  18         1860         741
# 20639    -121.24     39.37                  16         2785        1387
#
#        households  median_income  median_house_value ocean_proximity
# ...

# %%
df1.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                  41          880         322
# 1        -122.22     37.86                  21         7099        2401
# 2        -122.24     37.85                  52         1467         496
# 3        -122.25     37.85                  52         1274         558
# 4        -122.25     37.85                  52         1627         565
# ...          ...       ...                 ...          ...         ...
# 20635    -121.09     39.48                  25         1665         845
# 20636    -121.21     39.49                  18          697         356
# 20637    -121.22     39.43                  17         2254        1007
# 20638    -121.32     39.43                  18         1860         741
# 20639    -121.24     39.37                  16         2785        1387
#
#        households  median_income  median_house_value ocean_proximity
# ...

# %%
x = df1[['median_house_value']]
y = df1['total_rooms']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#        median_house_value
# 14196              103000
# 8267               382100
# 17445              172600
# 14265               93400
# 2271                96500
# ...                   ...
# 11284              229200
# 11964               97800
# 5390               222100
# 860                283500
# 15795              325000
#
# [16512 rows x 1 columns]

# %%
x_test
# Out:
#        median_house_value
# 20046               47700
# 3024                45800
# 15663              500001
# 20484              218600
# 9814               278000
# ...                   ...
# 15362              263300
# 16623              266800
# 18086              500001
# 2144                72300
# 3665               151500
#
# [4128 rows x 1 columns]

# %%
y_train
# Out:
# 14196    3126
# 8267     3382
# 17445    1897
# 14265    1421
# 2271     2382
#          ...
# 11284    1330
# 11964    3084
# 5390     2101
# 860      3575
# 15795    4226
# Name: total_rooms, Length: 16512, dtype: int64

# %%
y_test
# Out:
# 20046    1505
# 3024     2943
# 15663    3830
# 20484    3051
# 9814     2351
#          ...
# 15362    3165
# 16623    4323
# 18086    4111
# 2144     2507
# 3665     1787
# Name: total_rooms, Length: 4128, dtype: int64

# %%
model =  LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample = [[5]]
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print ("predicted total_rooms =",prediction)
# Out:
# predicted total_rooms = [2119.86951798]

# %%
numeric_df = df1.select_dtypes(include=['number'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(numeric_df.corr(), annot=True, cmap='viridis')
plt.show()

# %% [raw]
# 6. Medical Insurance Cost

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df2 = pd.read_csv(r"C:\Users\USER\Downloads\insurance (2).csv")

# %%
df2
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df2.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df2.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df2.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df2.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
x = df2[['charges']]
y = df2['age']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#           charges
# 560    9193.83850
# 1285   8534.67180
# 1142  27117.99378
# 969    8596.82780
# 486   12475.35130
# ...           ...
# 1095   4561.18850
# 1130   8582.30230
# 1294  11931.12525
# 860   46113.51100
# 1126  10214.63600
#
# [1070 rows x 1 columns]

# %%
x_test
# Out:
#           charges
# 764    9095.06825
# 887    5272.17580
# 890   29330.98315
# 1293   9301.89355
# 259   33750.29180
# ...           ...
# 109   47055.53210
# 575   12222.89830
# 535    6067.12675
# 543   63770.42801
# 846    9872.70100
#
# [268 rows x 1 columns]

# %%
y_train
# Out:
# 560     46
# 1285    47
# 1142    52
# 969     39
# 486     54
#         ..
# 1095    18
# 1130    39
# 1294    58
# 860     37
# 1126    55
# Name: age, Length: 1070, dtype: int64

# %%
y_test
# Out:
# 764     45
# 887     36
# 890     64
# 1293    46
# 259     19
#         ..
# 109     63
# 575     58
# 535     38
# 543     54
# 846     51
# Name: age, Length: 268, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample = [[5]]
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("predicted age=",prediction)
# Out:
# predicted age= [34.95612689]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_df = df2.select_dtypes(include = ['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
plt.show()

# %% [raw]
# 8. Car Price Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df3 = pd.read_csv(r'C:\Users\USER\Downloads\CarPrice_Assignment.csv')

# %%
df3
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df3.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df3.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df3.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df3.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df3 = df3.drop(columns = ['car_ID'])
df3 = df3.drop(columns = ['symboling'])
df3 = df3.drop(columns = ['enginelocation'])
df3 = df3.drop(columns = ['curbweight'])
df3 = df3.drop(columns = ['stroke'])

# %%
df3
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3                 audi 100 ls      gas        std       four        sedan
# 4                  audi 100ls      gas        std       four        sedan
# ..                        ...      ...        ...        ...          ...
# 200           volvo 145e (sw)      gas        std       four        sedan
# 201               volvo 144ea      gas      turbo       four        sedan
# 202               volvo 244dl      gas        std       four        sedan
# 203                 volvo 246   diesel      turbo       four        sedan
# 204               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  ... cylindernumber  \
# ...

# %%
df3.isnull().sum()
# Out:
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
x = df3 [['horsepower']]
y = df3['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#      horsepower
# 66           72
# 111          95
# 153          62
# 96           69
# 38           86
# ..          ...
# 106         160
# 14          121
# 92           69
# 179         161
# 102         152
#
# [164 rows x 1 columns]

# %%
x_test
# Out:
#      horsepower
# 15          182
# 9           160
# 100          97
# 132         110
# 68          123
# 95           69
# 159          56
# 162          70
# 147          94
# 182          52
# 191         110
# 164          70
# 65          120
# 175          92
# 73          184
# 152          62
# 18           48
# 82          145
# 86           88
# 143          94
# 60           84
# 101         152
# 98           69
# 30           58
# 25           68
# 16          182
# 168         116
# 195         114
# 97           69
# 194         114
# 67          123
# 120          68
# 154          62
# 202         134
# 79          102
# 69          123
# 145         111
# 55          101
# 45           70
# 84          145
# 146          82

# %%
y_train
# Out:
# 66     18344.0
# 111    15580.0
# 153     6918.0
# 96      7499.0
# 38      9095.0
#         ...
# 106    18399.0
# 14     24565.0
# 92      6849.0
# 179    15998.0
# 102    14399.0
# Name: price, Length: 164, dtype: float64

# %%
y_test
# Out:
# 15     30760.000
# 9      17859.167
# 100     9549.000
# 132    11850.000
# 68     28248.000
# 95      7799.000
# 159     7788.000
# 162     9258.000
# 147    10198.000
# 182     7775.000
# 191    13295.000
# 164     8238.000
# 65     18280.000
# 175     9988.000
# 73     40960.000
# 152     6488.000
# 18      5151.000
# 82     12629.000
# 86      8189.000
# 143     9960.000
# 60      8495.000
# 101    13499.000
# 98      8249.000
# 30      6479.000
# 25      6692.000
# 16     41315.000
# 168     9639.000
# 195    13415.000
# 97      7999.000
# 194    12940.000
# 67     25552.000
# 120     6229.000
# 154     7898.000
# 202    21485.000
# 79      7689.000
# 69     28176.000
# 145    11259.000
# 55     10945.000
# 45      8916.500
# 84     14489.000
# 146     7463.000
# Name: price, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample =[[5]]
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print ("predictedprice =",prediction)
# Out:
# predictedprice = [-2346.06312396]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_df = df3.select_dtypes(include = ['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
plt.show()

# %% [raw]
# 11. Advertising Sales

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df4 = pd.read_csv(r"C:\Users\USER\Downloads\advertising.csv")

# %%
df4
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df4.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df4.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df4.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df4.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df4.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x = df4[['TV']]
y = df4['Sales']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#         TV
# 79   116.0
# 197  177.0
# 38    43.1
# 24    62.3
# 122  224.0
# ..     ...
# 106   25.0
# 14   204.1
# 92   217.7
# 179  165.6
# 102  280.2
#
# [160 rows x 1 columns]

# %%
x_test
# Out:
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4
# 124  229.5
# 16    67.8
# 148   38.0
# 93   250.9
# 65    69.0
# 60    53.5
# 84   213.5
# 67   139.3
# 125   87.2
# 132    8.4
# 9    199.8
# 18    69.2
# 55   198.9
# 75    16.9
# 150  280.7
# 104  238.2
# 135   48.3
# 137  273.7
# 164  117.2
# 76    27.5

# %%
y_train
# Out:
# 79     11.0
# 197    14.8
# 38     10.1
# 24      9.7
# 122    16.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    17.6
# 102    19.8
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    16.5
# 45     16.1
# 66     11.0
# 182     8.7
# 165    16.9
# 78      5.3
# 186    10.3
# 177    16.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65     11.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      15.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample=[[5]]
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("predictedSales =",prediction)
# Out:
# predictedSales = [7.28452315]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_df = df4.select_dtypes(include = ['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
plt.show()

# %% [raw]
# 12. Used Cars

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df5 = pd.read_csv(r'C:\Users\USER\Downloads\CAR DETAILS FROM CAR DEKHO.csv')

# %%
df5
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df5.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df5.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df5.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df5.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df5.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
x = df5 [['year']]
y = df5 ['selling_price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#       year
# 227   2017
# 964   2018
# 2045  2013
# 1025  2011
# 4242  2017
# ...    ...
# 3444  2006
# 466   2011
# 3092  2016
# 3772  2013
# 860   2013
#
# [3472 rows x 1 columns]

# %%
x_test
# Out:
#       year
# 3978  2010
# 1448  2019
# 2664  2008
# 17    2014
# 1634  2016
# ...    ...
# 3468  2007
# 3164  2015
# 416   2011
# 1616  2017
# 2480  2019
#
# [868 rows x 1 columns]

# %%
y_train
# Out:
# 227     1500000
# 964      500000
# 2045      92800
# 1025      95000
# 4242     685000
#          ...
# 3444     500000
# 466      133000
# 3092     665000
# 3772     250999
# 860      175000
# Name: selling_price, Length: 3472, dtype: int64

# %%
y_test
# Out:
# 3978    165000
# 1448    250000
# 2664    120000
# 17      450000
# 1634    730000
#          ...
# 3468    130000
# 3164    350000
# 416     150000
# 1616    650000
# 2480    575000
# Name: selling_price, Length: 868, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample = [[5]]
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("predictedselling_price =",prediction)
# Out:
# predictedselling_price = [-1.15675227e+08]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.heatmap(df5.corr(numeric_value = True),annot = True,cmap = 'viridis')
plt.show()
# numeric_df = df5.select_dtypes(include = ['number'])
# sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.heatmap(df5.corr(numeric_value = True),annot = True,cmap = 'viridis')
#       2 plt.show()
#       3 # numeric_df = df5.select_dtypes(include = ['number'])
#       4 # sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
#       5 # plt.show()
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'numeric_value'. Did you mean 'numeric_only'?

# %% [raw]
# 14. Student Scores

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df6 = pd.read_csv(r"C:\Users\USER\Downloads\StudentsPerformance.csv")

# %%
df6
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df6.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df6.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df6.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df6.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df6.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df6 = df6.drop(columns = ['lunch'])

# %%
df6
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# ...

# %%
x = df6[['math score']]
y = df6['writing score']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#      math score
# 29           62
# 535          66
# 695          79
# 557          61
# 836          73
# ..          ...
# 106          87
# 270          69
# 860          53
# 435          50
# 102          85
#
# [800 rows x 1 columns]

# %%
x_test
# Out:
#      math score
# 521          91
# 737          53
# 740          80
# 660          74
# 411          84
# ..          ...
# 408          52
# 332          62
# 208          74
# 613          65
# 78           61
#
# [200 rows x 1 columns]

# %%
y_train
# Out:
# 29      75
# 535     83
# 695     86
# 557     66
# 836     57
#       ...
# 106    100
# 270     61
# 860     53
# 435     53
# 102     89
# Name: writing score, Length: 800, dtype: int64

# %%
y_test
# Out:
# 521    84
# 737    73
# 740    72
# 660    73
# 411    78
#        ..
# 408    56
# 332    53
# 208    76
# 613    74
# 78     72
# Name: writing score, Length: 200, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample = [[5]]
prediction = model.predict (sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("predictedmath score =",prediction)
# Out:
# predictedmath score = [18.91061811]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numeric_df = df6.select_dtypes(include = ['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
plt.show()

# %% [raw]
# 15. Weather vs Energy Consumption

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df7 = pd.read_csv(r"C:\Users\USER\Downloads\AEP_hourly.csv")

# %%
df7
# Out:
#                Datetime  AEP_MW
# 0       12/31/2004 1:00   13478
# 1       12/31/2004 2:00   12865
# 2       12/31/2004 3:00   12577
# 3       12/31/2004 4:00   12517
# 4       12/31/2004 5:00   12670
# ...                 ...     ...
# 121268   1/1/2018 20:00   21089
# 121269   1/1/2018 21:00   20999
# 121270   1/1/2018 22:00   20820
# 121271   1/1/2018 23:00   20415
# 121272    1/2/2018 0:00   19993
#
# [121273 rows x 2 columns]

# %%
df7.head()
# Out:
#           Datetime  AEP_MW
# 0  12/31/2004 1:00   13478
# 1  12/31/2004 2:00   12865
# 2  12/31/2004 3:00   12577
# 3  12/31/2004 4:00   12517
# 4  12/31/2004 5:00   12670

# %%
df7.tail()
# Out:
#               Datetime  AEP_MW
# 121268  1/1/2018 20:00   21089
# 121269  1/1/2018 21:00   20999
# 121270  1/1/2018 22:00   20820
# 121271  1/1/2018 23:00   20415
# 121272   1/2/2018 0:00   19993

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.9+ MB

# %%
df7.describe()
# Out:
#               AEP_MW
# count  121273.000000
# mean    15499.513717
# std      2591.399065
# min      9581.000000
# 25%     13630.000000
# 50%     15310.000000
# 75%     17200.000000
# max     25695.000000

# %%
df7.isnull().sum()
# Out:
# Datetime    0
# AEP_MW      0
# dtype: int64

# %%
df7.columns
# Out:
# Index(['Datetime', 'AEP_MW'], dtype='object')

# %%
df7 = df7.drop('Datetime',axis=1)

# %%
df7
# Out:
#         AEP_MW
# 0        13478
# 1        12865
# 2        12577
# 3        12517
# 4        12670
# ...        ...
# 121268   21089
# 121269   20999
# 121270   20820
# 121271   20415
# 121272   19993
#
# [121273 rows x 1 columns]

# %%
x= df7[['AEP_MW']]
y= df7['AEP_MW']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#         AEP_MW
# 37503    15189
# 4159     15242
# 91120    11930
# 70790    15600
# 98616    13655
# ...        ...
# 110268   11780
# 119879   13542
# 103694   17043
# 860      15231
# 15795    14413
#
# [97018 rows x 1 columns]

# %%
x_test
# Out:
#        AEP_MW
# 2685    19232
# 26514   13300
# 35136   16556
# 99429   14876
# 98733   13478
# ...       ...
# 42206   12422
# 97238   18794
# 37513   18107
# 70113   11053
# 45637   21705
#
# [24255 rows x 1 columns]

# %%
y_train
# Out:
# 37503     15189
# 4159      15242
# 91120     11930
# 70790     15600
# 98616     13655
#           ...
# 110268    11780
# 119879    13542
# 103694    17043
# 860       15231
# 15795     14413
# Name: AEP_MW, Length: 97018, dtype: int64

# %%
y_test
# Out:
# 2685     19232
# 26514    13300
# 35136    16556
# 99429    14876
# 98733    13478
#          ...
# 42206    12422
# 97238    18794
# 37513    18107
# 70113    11053
# 45637    21705
# Name: AEP_MW, Length: 24255, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
sample =[[5]]
prediction = model.predict(sample)
# Out:
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print ("predictedAEP_MW =",prediction)
# Out:
# predictedAEP_MW = [5.]

# %%
numeric_df = df7.select_dtypes(include = ['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap=  'viridis')
plt.show()
