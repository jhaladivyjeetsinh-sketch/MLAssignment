# %% [raw]
# Multiple Linear Regression

# %% [raw]
# 35. Insurance Charges

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv(r'C:\Users\USER\Downloads\insurance (3).csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x = df [['charges']]
y = df ['bmi']

# %%
x
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
y
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2 ,random_state = 42)

# %%
x_train
# Out:
#           charges
# 560    9193.83850
# 1285   8534.67180
# 1142  27117.99378
# 969    8596.82780
# 486   12475.35130
# ...           ...
# 1095   4561.18850
# 1130   8582.30230
# 1294  11931.12525
# 860   46113.51100
# 1126  10214.63600
#
# [1070 rows x 1 columns]

# %%
x_test
# Out:
#           charges
# 764    9095.06825
# 887    5272.17580
# 890   29330.98315
# 1293   9301.89355
# 259   33750.29180
# ...           ...
# 109   47055.53210
# 575   12222.89830
# 535    6067.12675
# 543   63770.42801
# 846    9872.70100
#
# [268 rows x 1 columns]

# %%
y_train
# Out:
# 560     19.950
# 1285    24.320
# 1142    24.860
# 969     34.320
# 486     21.470
#          ...
# 1095    31.350
# 1130    23.870
# 1294    25.175
# 860     47.600
# 1126    29.900
# Name: bmi, Length: 1070, dtype: float64

# %%
y_test
# Out:
# 764     25.175
# 887     30.020
# 890     26.885
# 1293    25.745
# 259     31.920
#          ...
# 109     35.090
# 575     27.170
# 535     28.025
# 543     47.410
# 846     34.200
# Name: bmi, Length: 268, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([30.13865235, 29.75938229, 32.14626224, 30.15917154, 32.58470289,
#        29.68637181, 29.44639017, 30.64615911, 29.6066431 , 30.25466621,
#        31.04782961, 29.9562697 , 29.62795227, 33.81499243, 34.06524373,
#        33.62168417, 30.20867692, 33.4993777 , 30.05313603, 31.39656412,
#        29.74032601, 29.97460156, 29.36096621, 29.50965477, 30.33613217,
#        30.32009448, 30.49080114, 31.10195241, 30.20023936, 29.34858552,
#        30.80670962, 30.41123798, 29.43678796, 29.80117507, 29.52444374,
#        29.9752864 , 29.49405475, 29.9643082 , 31.60622913, 33.07667496,
#        29.70140593, 29.49856778, 30.39452168, 30.43925184, 29.72146649,
#        30.45997047, 29.59148414, 29.67202532, 33.41551158, 29.67912412,
#        30.61408127, 29.40691417, 32.06151208, 29.40587141, 30.28738412,
#        31.74965441, 29.59795867, 33.08036351, 30.41178535, 30.28447317,
#        30.61346071, 29.70793792, 32.00839021, 30.03170301, 31.52268454,
# ...

# %%
df ['smoker'] = df['smoker'].map({'yes':1,'no':0})
df ['sex'] = df['sex'].map({'male':1,'female':0})

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  NaN  27.900         0     NaN       3  16884.92400
# 1      18  NaN  33.770         1     NaN       2   1725.55230
# 2      28  NaN  33.000         3     NaN       2   4449.46200
# 3      33  NaN  22.705         0     NaN       1  21984.47061
# 4      32  NaN  28.880         0     NaN       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  NaN  30.970         3     NaN       1  10600.54830
# 1334   18  NaN  31.920         0     NaN       0   2205.98080
# 1335   18  NaN  36.850         0     NaN       2   1629.83350
# 1336   21  NaN  25.800         0     NaN       3   2007.94500
# 1337   61  NaN  29.070         0     NaN       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 10
#       7 df['region'] = le.fit_transform(df['region'])
#       9 sns.heatmap(df.corr(), annot=True, cmap='viridis')
# ---> 10 plt.show()
#
# NameError: name 'plt' is not defined

# %% [raw]
# 33. Automobile

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df1 = pd.read_csv(r'C:\Users\USER\Downloads\Automobile_data.csv')

# %%
df1
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df1.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df1.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df1.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df1 = df1.drop(columns =['normalized-losses'])
df1 = df1.drop(columns =['height'])
df1 = df1.drop(columns =['bore'])

# %%
df1
# Out:
#      symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero       gas        std          two  convertible
# 1            3  alfa-romero       gas        std          two  convertible
# 2            1  alfa-romero       gas        std          two    hatchback
# 3            2         audi       gas        std         four        sedan
# 4            2         audi       gas        std         four        sedan
# ..         ...          ...       ...        ...          ...          ...
# 200         -1        volvo       gas        std         four        sedan
# 201         -1        volvo       gas      turbo         four        sedan
# 202         -1        volvo       gas        std         four        sedan
# 203         -1        volvo    diesel      turbo         four        sedan
# 204         -1        volvo       gas      turbo         four        sedan
#
# ...

# %%
x = df1 [['price']]
y = df1 ['fuel-type']

# %%
x
# Out:
#      price
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# ..     ...
# 200  16845
# 201  19045
# 202  21485
# 203  22470
# 204  22625
#
# [205 rows x 1 columns]

# %%
y
# Out:
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 200       gas
# 201       gas
# 202       gas
# 203    diesel
# 204       gas
# Name: fuel-type, Length: 205, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#      price
# 66   18344
# 111  15580
# 153   6918
# 96    7499
# 38    9095
# ..     ...
# 106  18399
# 14   24565
# 92    6849
# 179  15998
# 102  14399
#
# [164 rows x 1 columns]

# %%
x_test
# Out:
#      price
# 15   30760
# 9        ?
# 100   9549
# 132  11850
# 68   28248
# 95    7799
# 159   7788
# 162   9258
# 147  10198
# 182   7775
# 191  13295
# 164   8238
# 65   18280
# 175   9988
# 73   40960
# 152   6488
# 18    5151
# 82   12629
# 86    8189
# 143   9960
# 60    8495
# 101  13499
# 98    8249
# 30    6479
# 25    6692
# 16   41315
# 168   9639
# 195  13415
# 97    7999
# 194  12940
# 67   25552
# 120   6229
# 154   7898
# 202  21485
# 79    7689
# 69   28176
# 145  11259
# 55   10945
# 45       ?
# 84   14489
# 146   7463

# %%
y_train
# Out:
# 66     diesel
# 111       gas
# 153       gas
# 96        gas
# 38        gas
#         ...
# 106       gas
# 14        gas
# 92        gas
# 179       gas
# 102       gas
# Name: fuel-type, Length: 164, dtype: object

# %%
y_test
# Out:
# 15        gas
# 9         gas
# 100       gas
# 132       gas
# 68     diesel
# 95        gas
# 159    diesel
# 162       gas
# 147       gas
# 182    diesel
# 191       gas
# 164       gas
# 65        gas
# 175       gas
# 73        gas
# 152       gas
# 18        gas
# 82        gas
# 86        gas
# 143       gas
# 60        gas
# 101       gas
# 98        gas
# 30        gas
# 25        gas
# 16        gas
# 168       gas
# 195       gas
# 97        gas
# 194       gas
# 67     diesel
# 120       gas
# 154       gas
# 202       gas
# 79        gas
# 69     diesel
# 145       gas
# 55        gas
# 45        gas
# 84        gas
# 146       gas
# Name: fuel-type, dtype: object

# %%
df1.replace('?', '1000', inplace=True)

# %%
df1.head(60)
# Out:
#     symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0           3  alfa-romero       gas        std          two  convertible
# 1           3  alfa-romero       gas        std          two  convertible
# 2           1  alfa-romero       gas        std          two    hatchback
# 3           2         audi       gas        std         four        sedan
# 4           2         audi       gas        std         four        sedan
# 5           2         audi       gas        std          two        sedan
# 6           1         audi       gas        std         four        sedan
# 7           1         audi       gas        std         four        wagon
# 8           1         audi       gas      turbo         four        sedan
# 9           0         audi       gas      turbo          two    hatchback
# 10          2          bmw       gas        std          two        sedan
# 11          0          bmw       gas        std         four        sedan
# ...

# %%
le = LabelEncoder()
df1['fuel-type'] = le.fit_transform(df1['fuel-type'])

# %%
df1
# Out:
#      symboling         make  fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero          1        std          two  convertible
# 1            3  alfa-romero          1        std          two  convertible
# 2            1  alfa-romero          1        std          two    hatchback
# 3            2         audi          1        std         four        sedan
# 4            2         audi          1        std         four        sedan
# ..         ...          ...        ...        ...          ...          ...
# 200         -1        volvo          1        std         four        sedan
# 201         -1        volvo          1      turbo         four        sedan
# 202         -1        volvo          1        std         four        sedan
# 203         -1        volvo          0      turbo         four        sedan
# 204         -1        volvo          1      turbo         four        sedan
#
# ...

# %%
le = LabelEncoder()
df1['make'] = le.fit_transform(df1['make'])

# %%
le = LabelEncoder()
df1['aspiration'] = le.fit_transform(df1['aspiration'])

# %%
le = LabelEncoder()
df1['num-of-doors'] = le.fit_transform(df1['num-of-doors'])

# %%
le = LabelEncoder()
df1['body-style'] = le.fit_transform(df1['body-style'])
df1['drive-wheels'] = le.fit_transform(df1['drive-wheels'])
df1['engine-location'] = le.fit_transform(df1['engine-location'])

# %%
le = LabelEncoder()
df1['num-of-cylinders'] = le.fit_transform(df1['num-of-cylinders'])

# %%
le = LabelEncoder()
df1['engine-type'] = le.fit_transform(df1['engine-type'])

# %%
df1 = df1.drop(columns =['fuel-system'])

# %%
df1
# Out:
#      symboling  make  fuel-type  aspiration  num-of-doors  body-style  \
# 0            3     0          1           0             2           0
# 1            3     0          1           0             2           0
# 2            1     0          1           0             2           2
# 3            2     1          1           0             1           3
# 4            2     1          1           0             1           3
# ..         ...   ...        ...         ...           ...         ...
# 200         -1    21          1           0             1           3
# 201         -1    21          1           1             1           3
# 202         -1    21          1           0             1           3
# 203         -1    21          0           1             1           3
# 204         -1    21          1           1             1           3
#
#      drive-wheels  engine-location  wheel-base  length  ...  engine-type  \
# ...

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1384\1002171229.py in ?()
# ----> 1 model.fit(x_train,y_train)
#
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# F:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
#     616         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     617
# --> 618         X, y = validate_data(
#     619             self,
#     620             X,
#     621             y,
#
# ...

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([6.44978646, 8.50809532, 8.01048219, ..., 4.88909073, 6.04264844,
#        5.09265974], shape=(1477,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df1.corr(), annot=True, cmap='viridis')
plt.show()

# %%
37. World Happiness

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df2 = pd.read_csv(r"C:\Users\USER\Downloads\2015.csv")

# %%
df2
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df2.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df2.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df2.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df2.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
le = LabelEncoder()
df2['Region'] = le.fit_transform(df2['Region'])
df2['Country'] = le.fit_transform(df2['Country'])

# %%
df2
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
x = df2.drop('Dystopia Residual',axis= 1)
y = df2['Dystopia Residual']

# %%
x
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
#         ...
# 153    0.67042
# 154    1.63328
# 155    0.32858
# 156    1.83302
# 157    1.56726
# Name: Dystopia Residual, Length: 158, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size= 0.2,random_state = 42)

# %%
x_train
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 137       87       8             138            3.995         0.05602
# 55        81       1              56            5.833         0.03843
# 126        5       1             127            4.350         0.04763
# 84       156       8              85            5.129         0.06988
# 154       13       8             155            3.340         0.03656
# ..       ...     ...             ...              ...             ...
# 71        56       2              72            5.474         0.05051
# 106      143       4             107            4.739         0.03589
# 14       150       5              15            7.119         0.03839
# 92        83       1              93            5.007         0.05376
# 102       77       4             103            4.839         0.04337
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
x_test
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 128       97       6             129            4.307         0.04351
# 45        68       2              46            5.987         0.03581
# 134       41       4             135            4.194         0.03260
# 156       21       8             157            2.905         0.08658
# 90       126       8              91            5.057         0.06161
# 29         4       3              30            6.574         0.04612
# 96        78       8              97            4.898         0.09438
# 98        75       6              99            4.876         0.06698
# 95        16       1              96            4.949         0.06913
# 140      146       8             141            3.931         0.04317
# 19       148       4              20            6.901         0.03729
# 56       101       3              57            5.828         0.05371
# ...

# %%
y_train
# Out:
# 137    1.79293
# 55     2.44649
# 126    1.75873
# 84     2.63430
# 154    1.63328
#         ...
# 71     0.65429
# 106    2.12466
# 14     2.51011
# 92     1.73933
# 102    1.57059
# Name: Dystopia Residual, Length: 126, dtype: float64

# %%
y_test
# Out:
# 128    1.41805
# 45     1.68435
# 134    1.59927
# 156    1.83302
# 90     2.11032
# 29     2.83600
# 96     2.79832
# 98     1.73799
# 95     2.06367
# 140    1.42766
# 19     2.24743
# 56     2.32407
# 15     3.26001
# 69     1.86984
# 24     2.84848
# 30     2.67782
# 122    2.51009
# 109    1.69440
# 93     3.05137
# 65     1.59888
# 150    1.41723
# 18     2.41484
# 12     2.53320
# 9      2.26646
# 31     2.32142
# 81     1.87996
# 51     3.10712
# 139    1.95812
# 125    2.05125
# 146    1.85100
# 145    1.38079
# 75     2.08528
# Name: Dystopia Residual, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df2.corr(), annot=True, cmap='viridis')
plt.show()

# %% [raw]
# 38. CO₂ Emissions by Vehicles

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df3 = pd.read_csv(r'C:\Users\USER\Downloads\CO2 Emissions_Canada.csv')

# %%
df3
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df3.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
df3.tail()
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 7380                              7.7                               9.4
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
df3.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df3.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df3.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
le = LabelEncoder()
df3['Make'] = le.fit_transform(df3['Make'])
df3['Model'] = le.fit_transform(df3['Model'])   
df3['Vehicle Class'] = le.fit_transform(df3['Vehicle Class'])  
df3['Transmission'] = le.fit_transform(df3['Transmission'])  
df3['Fuel Type'] = le.fit_transform(df3['Fuel Type'])

# %%
df3
# Out:
#       Make  Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0        0   1057              0             2.0          4            14
# 1        0   1057              0             2.4          4            25
# 2        0   1058              0             1.5          4            22
# 3        0   1233             11             3.5          6            15
# 4        0   1499             11             3.5          6            15
# ...    ...    ...            ...             ...        ...           ...
# 7380    41   1951             11             2.0          4            17
# 7381    41   1957             11             2.0          4            17
# 7382    41   1960             11             2.0          4            17
# 7383    41   1968             12             2.0          4            17
# 7384    41   1969             12             2.0          4            17
#
#       Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
x = df3[['CO2 Emissions(g/km)']]
y = df3 ['Vehicle Class']

# %%
x
# Out:
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...                   ...
# 7380                  219
# 7381                  232
# 7382                  240
# 7383                  232
# 7384                  248
#
# [7385 rows x 1 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3       11
# 4       11
#         ..
# 7380    11
# 7381    11
# 7382    11
# 7383    12
# 7384    12
# Name: Vehicle Class, Length: 7385, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#       CO2 Emissions(g/km)
# 6590                  231
# 6274                  299
# 2251                  273
# 3149                  230
# 4362                  204
# ...                   ...
# 5191                  210
# 5226                  214
# 5390                  242
# 860                   198
# 7270                  279
#
# [5908 rows x 1 columns]

# %%
x_test
# Out:
#       CO2 Emissions(g/km)
# 7261                  253
# 4489                  344
# 1539                  322
# 3532                  297
# 6418                  308
# ...                   ...
# 7185                  221
# 1740                  260
# 4609                  184
# 1844                  235
# 5154                  193
#
# [1477 rows x 1 columns]

# %%
y_train
# Out:
# 6590    10
# 6274     5
# 2251     0
# 3149    13
# 4362     8
#         ..
# 5191    10
# 5226     2
# 5390    12
# 860     11
# 7270     1
# Name: Vehicle Class, Length: 5908, dtype: int64

# %%
y_test
# Out:
# 7261     1
# 4489    10
# 1539     6
# 3532     6
# 6418    12
#         ..
# 7185    10
# 1740    11
# 4609     9
# 1844     2
# 5154     0
# Name: Vehicle Class, Length: 1477, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([6.44978646, 8.50809532, 8.01048219, ..., 4.88909073, 6.04264844,
#        5.09265974], shape=(1477,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df3.corr(), annot=True, cmap='viridis')
plt.show()

# %%
39. 50 Startups Profit

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df4 = pd.read_csv(r'C:\Users\USER\Downloads\50_Startups.csv')

# %%
df4
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df4.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df4.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df4.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df4.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df4.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
le = LabelEncoder()
df4['State'] = le.fit_transform(df4['State'])

# %%
x = df4.drop('Profit',axis = 1)
y = df4['Profit']

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0   165349.20       136897.80        471784.10      2
# 1   162597.70       151377.59        443898.53      0
# 2   153441.51       101145.55        407934.54      1
# 3   144372.41       118671.85        383199.62      2
# 4   142107.34        91391.77        366168.42      1
# 5   131876.90        99814.71        362861.36      2
# 6   134615.46       147198.87        127716.82      0
# 7   130298.13       145530.06        323876.68      1
# 8   120542.52       148718.95        311613.29      2
# 9   123334.88       108679.17        304981.62      0
# 10  101913.08       110594.11        229160.95      1
# 11  100671.96        91790.61        249744.55      0
# 12   93863.75       127320.38        249839.44      1
# 13   91992.39       135495.07        252664.93      0
# 14  119943.24       156547.42        256512.92      1
# 15  114523.61       122616.84        261776.23      2
# ...

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 12   93863.75       127320.38        249839.44      1
# 4   142107.34        91391.77        366168.42      1
# 37   44069.95        51283.14        197029.42      0
# 8   120542.52       148718.95        311613.29      2
# 3   144372.41       118671.85        383199.62      2
# 6   134615.46       147198.87        127716.82      0
# 41   27892.92        84710.77        164470.71      1
# 46    1315.46       115816.21        297114.46      1
# 47       0.00       135426.92             0.00      0
# 15  114523.61       122616.84        261776.23      2
# 9   123334.88       108679.17        304981.62      0
# 16   78013.11       121597.55        264346.06      0
# 24   77044.01        99281.34        140574.81      2
# 34   46426.07       157693.92        210797.67      0
# 31   61136.38       152701.92         88218.23      2
# 0   165349.20       136897.80        471784.10      2
# ...

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 13   91992.39       135495.07        252664.93      0
# 39   38558.51        82982.09        174999.30      0
# 30   61994.48       115641.28         91131.24      1
# 45    1000.23       124153.04          1903.93      2
# 17   94657.16       145077.58        282574.31      2
# 48     542.05        51743.15             0.00      2
# 26   75328.87       144135.98        134050.07      1
# 25   64664.71       139553.16        137962.62      0
# 32   63408.86       129219.61         46085.25      0
# 19   86419.70       153514.11             0.00      2

# %%
y_train
# Out:
# 12    141585.52
# 4     166187.94
# 37     89949.14
# 8     152211.77
# 3     182901.99
# 6     156122.51
# 41     77798.83
# 46     49490.75
# 47     42559.73
# 15    129917.04
# 9     149759.96
# 16    126992.93
# 24    108552.04
# 34     96712.80
# 31     97483.56
# 0     192261.83
# 44     65200.33
# 27    105008.31
# 33     96778.92
# 5     156991.12
# 29    101004.64
# 11    144259.40
# 36     90708.19
# 1     191792.06
# 21    111313.02
# 2     191050.39
# 43     69758.98
# 35     96479.51
# 23    108733.99
# 40     78239.91
# 10    146121.95
# 22    110352.25
# 18    124266.90
# 49     14681.40
# 20    118474.03
# 7     155752.60
# 42     71498.49
# 14    132602.65
# 28    103282.38
# 38     81229.06
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 13    134307.35
# 39     81005.76
# 30     99937.59
# 45     64926.08
# 17    125370.37
# 48     35673.41
# 26    105733.54
# 25    107404.34
# 32     97427.84
# 19    122776.86
# Name: Profit, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([126720.66150723,  84909.08961912,  98890.31854876,  46479.31240248,
#        129113.18318813,  50968.88397762, 109015.01626803, 100893.57078084,
#         97713.73821431, 113085.59056068])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df4.corr(), annot=True, cmap='viridis')
plt.show()

# %% [raw]
# 40. Diamonds Price

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df5 = pd.read_csv(r'C:\Users\USER\Downloads\diamonds.csv')

# %%
df5
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df5.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df5.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df5.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df5.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df5.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
le = LabelEncoder()
df5['cut'] = le.fit_transform(df5['cut'])
df5['color'] = le.fit_transform(df5['color'])
df5['clarity'] = le.fit_transform(df5['clarity'])

# %%
df5
# Out:
#        Unnamed: 0  carat  cut  color  clarity  depth  table  price     x  \
# 0               1   0.23    2      1        3   61.5   55.0    326  3.95
# 1               2   0.21    3      1        2   59.8   61.0    326  3.89
# 2               3   0.23    1      1        4   56.9   65.0    327  4.05
# 3               4   0.29    3      5        5   62.4   58.0    334  4.20
# 4               5   0.31    1      6        3   63.3   58.0    335  4.34
# ...           ...    ...  ...    ...      ...    ...    ...    ...   ...
# 53935       53936   0.72    2      0        2   60.8   57.0   2757  5.75
# 53936       53937   0.72    1      0        2   63.1   55.0   2757  5.69
# 53937       53938   0.70    4      0        2   62.8   60.0   2757  5.66
# 53938       53939   0.86    3      4        3   61.0   58.0   2757  6.15
# 53939       53940   0.75    2      0        3   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# ...

# %%
x = df5[['price']]
y = df5 ['carat']

# %%
x
# Out:
#        price
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
# ...      ...
# 53935   2757
# 53936   2757
# 53937   2757
# 53938   2757
# 53939   2757
#
# [53940 rows x 1 columns]

# %%
y
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#        price
# 26546  16231
# 9159    4540
# 14131   5729
# 15757   6300
# 24632  12968
# ...      ...
# 11284   4975
# 44732   1617
# 38158   1014
# 860     2871
# 15795   6320
#
# [43152 rows x 1 columns]

# %%
x_test
# Out:
#        price
# 1388     559
# 50052   2201
# 41645   1238
# 42377   1304
# 17244   6901
# ...      ...
# 44081   1554
# 23713    633
# 31375    761
# 21772   9836
# 4998    3742
#
# [10788 rows x 1 columns]

# %%
y_train
# Out:
# 26546    2.01
# 9159     1.01
# 14131    1.10
# 15757    1.50
# 24632    1.52
#          ...
# 11284    1.05
# 44732    0.47
# 38158    0.33
# 860      0.90
# 15795    1.14
# Name: carat, Length: 43152, dtype: float64

# %%
y_test
# Out:
# 1388     0.24
# 50052    0.58
# 41645    0.40
# 42377    0.43
# 17244    1.55
#          ...
# 44081    0.50
# 23713    0.25
# 31375    0.31
# 21772    1.23
# 4998     1.08
# Name: carat, Length: 10788, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([0.42862378, 0.60815354, 0.50286294, ..., 0.45070966, 1.44293416,
#        0.77664037], shape=(10788,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df5.corr(), annot=True, cmap='viridis')
plt.show()

# %% [raw]
# 43. Crop Yield Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df6 = pd.read_csv(r'C:\Users\USER\Downloads\pesticides.csv')

# %%
df6
# Out:
#               Domain      Area Element                Item  Year  \
# 0     Pesticides Use   Albania     Use  Pesticides (total)  1990
# 1     Pesticides Use   Albania     Use  Pesticides (total)  1991
# 2     Pesticides Use   Albania     Use  Pesticides (total)  1992
# 3     Pesticides Use   Albania     Use  Pesticides (total)  1993
# 4     Pesticides Use   Albania     Use  Pesticides (total)  1994
# ...              ...       ...     ...                 ...   ...
# 4344  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2012
# 4345  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2013
# 4346  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2014
# 4347  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2015
# 4348  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2016
#
#                               Unit    Value
# 0     tonnes of active ingredients   121.00
# 1     tonnes of active ingredients   121.00
# 2     tonnes of active ingredients   121.00
# ...

# %%
df6.head()
# Out:
#            Domain     Area Element                Item  Year  \
# 0  Pesticides Use  Albania     Use  Pesticides (total)  1990
# 1  Pesticides Use  Albania     Use  Pesticides (total)  1991
# 2  Pesticides Use  Albania     Use  Pesticides (total)  1992
# 3  Pesticides Use  Albania     Use  Pesticides (total)  1993
# 4  Pesticides Use  Albania     Use  Pesticides (total)  1994
#
#                            Unit  Value
# 0  tonnes of active ingredients  121.0
# 1  tonnes of active ingredients  121.0
# 2  tonnes of active ingredients  121.0
# 3  tonnes of active ingredients  121.0
# 4  tonnes of active ingredients  201.0

# %%
df6.tail()
# Out:
#               Domain      Area Element                Item  Year  \
# 4344  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2012
# 4345  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2013
# 4346  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2014
# 4347  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2015
# 4348  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2016
#
#                               Unit    Value
# 4344  tonnes of active ingredients  3375.53
# 4345  tonnes of active ingredients  2550.07
# 4346  tonnes of active ingredients  2185.07
# 4347  tonnes of active ingredients  2185.07
# 4348  tonnes of active ingredients  2185.07

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4349 entries, 0 to 4348
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Domain   4349 non-null   object
#  1   Area     4349 non-null   object
#  2   Element  4349 non-null   object
#  3   Item     4349 non-null   object
#  4   Year     4349 non-null   int64
#  5   Unit     4349 non-null   object
#  6   Value    4349 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 238.0+ KB

# %%
df6.describe()
# Out:
#               Year         Value
# count  4349.000000  4.349000e+03
# mean   2003.138883  2.030334e+04
# std       7.728044  1.177362e+05
# min    1990.000000  0.000000e+00
# 25%    1996.000000  9.300000e+01
# 50%    2003.000000  1.137560e+03
# 75%    2010.000000  7.869000e+03
# max    2016.000000  1.807000e+06

# %%
df6.isnull().sum()
# Out:
# Domain     0
# Area       0
# Element    0
# Item       0
# Year       0
# Unit       0
# Value      0
# dtype: int64

# %%
df6.columns
# Out:
# Index(['Domain', 'Area', 'Element', 'Item', 'Year', 'Unit', 'Value'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df6['Domain'] = le.fit_transform(df6['Domain'])
df6['Area'] = le.fit_transform(df6['Area'])
df6['Element'] = le.fit_transform(df6['Element'])
df6['Item'] = le.fit_transform(df6['Item'])
df6['Unit'] = le.fit_transform(df6['Unit'])

# %%
df6
# Out:
#       Domain  Area  Element  Item  Year  Unit    Value
# 0          0     0        0     0  1990     0   121.00
# 1          0     0        0     0  1991     0   121.00
# 2          0     0        0     0  1992     0   121.00
# 3          0     0        0     0  1993     0   121.00
# 4          0     0        0     0  1994     0   201.00
# ...      ...   ...      ...   ...   ...   ...      ...
# 4344       0   167        0     0  2012     0  3375.53
# 4345       0   167        0     0  2013     0  2550.07
# 4346       0   167        0     0  2014     0  2185.07
# 4347       0   167        0     0  2015     0  2185.07
# 4348       0   167        0     0  2016     0  2185.07
#
# [4349 rows x 7 columns]

# %%
x = df6[['Value']]
y = df6['Year']

# %%
x
# Out:
#         Value
# 0      121.00
# 1      121.00
# 2      121.00
# 3      121.00
# 4      201.00
# ...       ...
# 4344  3375.53
# 4345  2550.07
# 4346  2185.07
# 4347  2185.07
# 4348  2185.07
#
# [4349 rows x 1 columns]

# %%
y
# Out:
# 0       1990
# 1       1991
# 2       1992
# 3       1993
# 4       1994
#         ...
# 4344    2012
# 4345    2013
# 4346    2014
# 4347    2015
# 4348    2016
# Name: Year, Length: 4349, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#          Value
# 322     550.00
# 805   15373.00
# 2481     24.28
# 915    9954.00
# 1041      3.33
# ...        ...
# 3444    603.90
# 466       7.78
# 3092   8167.30
# 3772    235.40
# 860      17.15
#
# [3479 rows x 1 columns]

# %%
x_test
# Out:
#          Value
# 817   10939.18
# 4270    713.28
# 2409    202.35
# 3508   1595.47
# 2810   3490.00
# ...        ...
# 4101  19277.79
# 1189   2868.00
# 12      691.75
# 1936   2333.67
# 1034      2.79
#
# [870 rows x 1 columns]

# %%
y_train
# Out:
# 322     1992
# 805     1991
# 2481    1997
# 915     1993
# 1041    2011
#         ...
# 3444    2008
# 466     2003
# 3092    2003
# 3772    2005
# 860     1992
# Name: Year, Length: 3479, dtype: int64

# %%
y_test
# Out:
# 817     2003
# 4270    1994
# 2409    2006
# 3508    2007
# 2810    1991
#         ...
# 4101    2016
# 1189    2002
# 12      2002
# 1936    2001
# 1034    2004
# Name: Year, Length: 870, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([2003.10794985, 2003.08735833, 2003.08632949, 2003.08913476,
#        2003.09294971, 2003.08593209, 2003.0882035 , 2003.08677227,
#        2003.08642544, 2003.09625373, 2003.87508467, 2003.11350318,
#        2003.08597881, 2003.0868322 , 2003.1083784 , 2003.08624397,
#        2003.08594612, 2003.09483665, 2003.08794891, 2003.08595656,
#        2003.0863167 , 2003.15748615, 2003.11416362, 2003.19794818,
#        2003.08613346, 2003.15501083, 2003.10419487, 2003.08613346,
#        2003.08596964, 2003.09837444, 2003.10506016, 2003.09498149,
#        2003.13819875, 2003.27158183, 2003.12449174, 2003.08997754,
#        2003.08596807, 2003.12444543, 2003.10123596, 2003.08904209,
#        2003.08944946, 2003.08592975, 2003.08609721, 2003.08613346,
#        2003.24665505, 2003.08788492, 2003.12188731, 2003.08604687,
#        2003.08592585, 2003.08814329, 2003.08604687, 2003.08882129,
#        2003.14000299, 2003.08648327, 2003.13796516, 2003.10773955,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df6.corr(), annot=True, cmap='viridis')
plt.show()

# %%
46. Airbnb Price Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df7 = pd.read_csv(r'C:\Users\USER\Downloads\AB_NYC_2019.csv')

# %%
df7
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df7.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df7.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df7.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df7.isnull().sum()
# Out:
# name                                  0
# host_id                               0
# host_name                             0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df7.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df7 =df7.drop(columns = ['id'])
df7 = df7.drop(columns = ['neighbourhood_group'])
df7 = df7.drop(columns = ['neighbourhood'])

# %%
df7
# Out:
#                                                     name   host_id  \
# 0                     Clean & quiet apt home by the park      2787
# 1                                  Skylit Midtown Castle      2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3                        Cozy Entire Floor of Brownstone      4869
# 4       Entire Apt: Spacious Studio/Loft by central park      7192
# ...                                                  ...       ...
# 48890    Charming one bedroom - newly renovated rowhouse   8232441
# 48891      Affordable room in Bushwick/East Williamsburg   6570630
# 48892            Sunny Studio at Historical Neighborhood  23492952
# 48893               43rd St. Time Square-cozy single bed  30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude        room_type  price  \
# 0               John  40.64749  -73.97237     Private room    149
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df7['name'] = le.fit_transform(df7['name'])
df7['room_type'] = le.fit_transform(df7['room_type'])
df7['host_name'] = le.fit_transform(df7['host_name'])

# %%
df7
# Out:
#         name   host_id  host_name  latitude  longitude  room_type  price  \
# 0      12319      2787       4989  40.64749  -73.97237          1    149
# 1      37446      2845       4785  40.75362  -73.98377          0    225
# 2      43534      4632       2909  40.80902  -73.94190          1    150
# 3      14774      4869       6203  40.68514  -73.95976          0     89
# 4      18684      7192       5923  40.79851  -73.94399          0     80
# ...      ...       ...        ...       ...        ...        ...    ...
# 48890  11638   8232441       9051  40.67853  -73.94995          1     70
# 48891   3511   6570630       6776  40.70184  -73.93317          1     40
# 48892  42455  23492952       4263  40.81475  -73.94867          0    115
# 48893   2563  30985759      10190  40.75751  -73.99112          2     55
# 48894  44529  68119814       1968  40.76404  -73.98933          1     90
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df7 = df7.drop(columns = ['last_review'])

# %%
df7 ['reviews_per_month'] = df7 ['reviews_per_month'].ffill()

# %%
df7
# Out:
#         name   host_id  host_name  latitude  longitude  room_type  price  \
# 0      12319      2787       4989  40.64749  -73.97237          1    149
# 1      37446      2845       4785  40.75362  -73.98377          0    225
# 2      43534      4632       2909  40.80902  -73.94190          1    150
# 3      14774      4869       6203  40.68514  -73.95976          0     89
# 4      18684      7192       5923  40.79851  -73.94399          0     80
# ...      ...       ...        ...       ...        ...        ...    ...
# 48890  11638   8232441       9051  40.67853  -73.94995          1     70
# 48891   3511   6570630       6776  40.70184  -73.93317          1     40
# 48892  42455  23492952       4263  40.81475  -73.94867          0    115
# 48893   2563  30985759      10190  40.75751  -73.99112          2     55
# 48894  44529  68119814       1968  40.76404  -73.98933          1     90
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
df7.isnull().sum()
# Out:
# name                              0
# host_id                           0
# host_name                         0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
x = df7[['availability_365']]
y = df7['price']

# %%
x
# Out:
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 1 columns]

# %%
y
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#        availability_365
# 32645                 1
# 23615                 0
# 31183                 0
# 29260               267
# 7275                  0
# ...                 ...
# 11284                 0
# 44732                76
# 38158               261
# 860                   2
# 15795                 0
#
# [39116 rows x 1 columns]

# %%
x_test
# Out:
#        availability_365
# 879                 189
# 44383                73
# 15394                 0
# 43230               272
# 16332                30
# ...                 ...
# 20477                68
# 44969               294
# 36577                 5
# 11477                 0
# 1023                364
#
# [9779 rows x 1 columns]

# %%
y_train
# Out:
# 32645    295
# 23615     70
# 31183     58
# 29260     75
# 7275      38
#         ...
# 11284     60
# 44732     85
# 38158    130
# 860      150
# 15795    120
# Name: price, Length: 39116, dtype: int64

# %%
y_test
# Out:
# 879       89
# 44383     30
# 15394    120
# 43230    470
# 16332    199
#         ...
# 20477    215
# 44969    100
# 36577     70
# 11477    500
# 1023     125
# Name: price, Length: 9779, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([165.15629631, 147.64649622, 136.62739789, ..., 137.38213065,
#        136.62739789, 191.57194301], shape=(9779,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df7.corr(), annot=True, cmap='viridis')
plt.show()

# %%
47. Flight Fare Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df8 = pd.read_csv(r'C:\Users\USER\Downloads\Data_Train 1.csv')

# %%
df8
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df8.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df8.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU ? BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU ? BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR ? DEL    08:20        11:20       3h    non-stop
# 10681              BLR ? DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL ? GOI ? BOM ? COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df8.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df8.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df8.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df8['Total_Stops'] = df8['Route'].ffill()
df8['Route'] = df8['Route'].ffill()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
# df8['Airline'] = le.fit_transform(df8['Airline'])
# df8['Source'] = le.fit_transform(df8['Source'])
# df8['Destination'] = le.fit_transform(df8['Destination'])
# df8['Route'] = le.fit_transform(df8['Route'])
# df8['Total_Stops'] = le.fit_transform(df8['Total_Stops'])
# df8['Additional_Info'] = le.fit_transform(df8['Additional_Info'])
# #df8['Duration'] = le.fit_transfrom(df8['Duration'])
# df8['Date_of_Journey'] = le.fit_transfrom(df8['Date_of_Journey'])
df8['Dep_Time'] = le.fit_transfrom(df8['Dep_Time'])
df8['Arrival_Time'] = le.fit_transfrom(df8['Arrival_Time'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 10
#       1 le = LabelEncoder()
#       2 # df8['Airline'] = le.fit_transform(df8['Airline'])
#       3 # df8['Source'] = le.fit_transform(df8['Source'])
#       4 # df8['Destination'] = le.fit_transform(df8['Destination'])
#    (...)      8 # #df8['Duration'] = le.fit_transfrom(df8['Duration'])
#       9 # df8['Date_of_Journey'] = le.fit_transfrom(df8['Date_of_Journey'])
# ---> 10 df8['Dep_Time'] = le.fit_transfrom(df8['Dep_Time'])
#      11 df8['Arrival_Time'] = le.fit_transfrom(df8['Arrival_Time'])
#
# AttributeError: 'LabelEncoder' object has no attribute 'fit_transfrom'

# %%
df8
# Out:
#        Airline  Source  Destination  Route Dep_Time  Arrival_Time Duration  \
# 0            3       0            5     18    22:20  01:10 22 Mar   2h 50m
# 1            1       3            0     84    05:50         13:15   7h 25m
# 2            4       2            1    118    09:25  04:25 10 Jun      19h
# 3            3       3            0     91    18:05         23:30   5h 25m
# 4            3       0            5     29    16:50         21:35   4h 45m
# ...        ...     ...          ...    ...      ...           ...      ...
# 10678        0       3            0     64    19:55         22:25   2h 30m
# 10679        1       3            0     64    20:45         23:20   2h 35m
# 10680        4       0            2     18    08:20         11:20       3h
# 10681       10       0            5     18    11:30         14:10   2h 40m
# 10682        1       2            1    108    10:55         19:15   8h 20m
#
#        Total_Stops  Additional_Info  Price
# ...

# %%
df8.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
x = df8.drop('Price',axis = 1)
y = df8['Price']

# %%
x
# Out:
#        Airline  Source  Destination  Route  Total_Stops  Additional_Info
# 0            3       0            5     18           18                8
# 1            1       3            0     84           84                8
# 2            4       2            1    118          118                8
# 3            3       3            0     91           91                8
# 4            3       0            5     29           29                8
# ...        ...     ...          ...    ...          ...              ...
# 10678        0       3            0     64           64                8
# 10679        1       3            0     64           64                8
# 10680        4       0            2     18           18                8
# 10681       10       0            5     18           18                8
# 10682        1       2            1    108          108                8
#
# [10683 rows x 6 columns]

# %%
y
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 42)

# %%
x_train
# Out:
#       Airline  Source  Destination  Route  Total_Stops  Additional_Info
# 8990        4       4            3     58           58                8
# 3684        4       2            1    104          104                5
# 1034        8       2            1    121          121                8
# 3909        6       2            1    104          104                8
# 3088        1       2            1    110          110                8
# ...       ...     ...          ...    ...          ...              ...
# 5734        4       2            1    104          104                8
# 5191        4       3            0     66           66                5
# 5390        6       2            1    104          104                8
# 860         3       0            5     18           18                8
# 7270        4       2            1    104          104                5
#
# [8546 rows x 6 columns]

# %%
x_test
# Out:
#        Airline  Source  Destination  Route  Total_Stops  Additional_Info
# 6076         4       3            0     66           66                5
# 3544         2       2            1    104          104                8
# 7313         4       3            0     66           66                8
# 5032         3       1            4    127          127                8
# 2483         4       2            1    104          104                5
# ...        ...     ...          ...    ...          ...              ...
# 9797         6       2            1    104          104                8
# 9871         8       3            0     64           64                8
# 10063        0       2            1    103          103                8
# 7623         3       0            2     18           18                8
# 8618         4       3            0     66           66                8
#
# [2137 rows x 6 columns]

# %%
y_train
# Out:
# 8990    23528
# 3684    12373
# 1034     5583
# 3909     7695
# 3088    11972
#         ...
# 5734    12242
# 5191    10844
# 5390     7670
# 860      6144
# 7270    10262
# Name: Price, Length: 8546, dtype: int64

# %%
y_test
# Out:
# 6076     10844
# 3544      4959
# 7313     14781
# 5032      3858
# 2483     12898
#          ...
# 9797      7408
# 9871      4622
# 10063     7452
# 7623      4823
# 8618     13731
# Name: Price, Length: 2137, dtype: int64

# %%
# df8 = df8.drop(columns =['Date_of_Journey'])
#df8 = df8.drop(columns =['Arrival_Time'])
#df8 = df8.drop(columns =['Dep_Time'])
df8 = df8.drop(columns = ['Duration'])

# %%
model = LinearRegression()

# %%
model.fit (x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([ 9370.90467316,  9844.4387222 ,  8574.95804857, ...,
#        10032.2270492 ,  8203.0187806 ,  8574.95804857], shape=(2137,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df8.corr(), annot=True, cmap='viridis')
plt.show()

# %%
48. Used Bike Price Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df9 = pd.read_csv(r'C:\Users\USER\Downloads\BIKE DETAILS.csv')

# %%
df9
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df9.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df9.tail()
# Out:
#                     name  selling_price  year seller_type      owner  \
# 1056           Activa 3g          17000  2010  Individual  1st owner
# 1057    Honda CB twister          16000  2012  Individual  1st owner
# 1058  Bajaj Discover 125          15000  2013  Individual  2nd owner
# 1059      Honda CB Shine          12000  2009  Individual  1st owner
# 1060    Bajaj Pulsar 150          10000  2008  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 1056     500000            52000.0
# 1057      33000            51000.0
# 1058      35000            57000.0
# 1059      53000            58000.0
# 1060      92233            75000.0

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
df9.describe()
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
df9.isnull().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
df9.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df9['ex_showroom_price'] =df9['ex_showroom_price'].ffill()

# %%
df9.isnull().sum()
# Out:
# name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %%
df9['ex_showroom_price'] = df9 ['ex_showroom_price'].fillna (df9['ex_showroom_price'].mean())

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df9['name'] = le.fit_transform(df9['name'])
df9['seller_type'] = le.fit_transform(df9['seller_type'])
df9['owner'] = le.fit_transform(df9['owner'])

# %%
x = df9.drop('ex_showroom_price',axis =1)
y = df9['ex_showroom_price']

# %%
x
# Out:
#       name  selling_price  year  seller_type  owner  km_driven
# 0      179         175000  2019            1      0        350
# 1      145          45000  2017            1      0       5650
# 2      183         150000  2018            1      0      12000
# 3      260          65000  2015            1      0      23000
# 4      269          20000  2011            1      1      21000
# ...    ...            ...   ...          ...    ...        ...
# 1056     0          17000  2010            1      0     500000
# 1057   140          16000  2012            1      0      33000
# 1058    21          15000  2013            1      1      35000
# 1059   132          12000  2009            1      0      53000
# 1060    35          10000  2008            1      0      92233
#
# [1061 rows x 6 columns]

# %%
y
# Out:
# 0        89000.393768
# 1        89000.393768
# 2       148114.000000
# 3        89643.000000
# 4        89643.000000
#             ...
# 1056     52000.000000
# 1057     51000.000000
# 1058     57000.000000
# 1059     58000.000000
# 1060     75000.000000
# Name: ex_showroom_price, Length: 1061, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#       name  selling_price  year  seller_type  owner  km_driven
# 72      45          65000  2015            1      0      15856
# 898    147          30000  2015            1      1      46070
# 44     251          85000  2018            1      0       8000
# 309    126          42000  2018            1      0      22000
# 784    106          20000  2012            1      1      30000
# ...    ...            ...   ...          ...    ...        ...
# 330    201          45000  2017            1      0      15000
# 466    137          55000  2017            1      0      12000
# 121    241         160000  2018            1      0       7000
# 1044    35          25000  2010            1      1      26000
# 860    171         300000  2011            1      0      12000
#
# [848 rows x 6 columns]

# %%
x_test
# Out:
#      name  selling_price  year  seller_type  owner  km_driven
# 31    252          38000  2013            1      0      75000
# 413   202          16000  2011            1      0      40000
# 535    74          12000  2007            1      1     100000
# 743   203          27000  2012            1      0      14100
# 792   116         100000  2019            1      0       8500
# ..    ...            ...   ...          ...    ...        ...
# 581    69          30000  2014            1      1      35000
# 55     83          25000  2006            1      0      75000
# 120   197          83900  2014            1      1      22000
# 388    35           8000  2005            1      0      58000
# 25    147          25000  2012            1      0      35000
#
# [213 rows x 6 columns]

# %%
y_train
# Out:
# 72       92074.0
# 898      56147.0
# 44       84042.0
# 309      57557.0
# 784      49600.0
#           ...
# 330      64589.0
# 466      74295.0
# 121     180525.0
# 1044     75000.0
# 860     589000.0
# Name: ex_showroom_price, Length: 848, dtype: float64

# %%
y_test
# Out:
# 31      79432.0
# 413     58314.0
# 535     61600.0
# 743     70851.0
# 792    107500.0
#          ...
# 581     87042.0
# 55      59422.0
# 120     75936.0
# 388     95955.0
# 25      56147.0
# Name: ex_showroom_price, Length: 213, dtype: float64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([ 65351.78609244,  57325.14295135,  88599.38194642,  62460.96968874,
#         98969.45720157,  76471.10808381,  38320.89111724,  95426.66605859,
#         56955.2267737 ,  95583.27844411,  95058.75562676,  33462.89810814,
#        123742.26966478,  77876.33556667, 184657.76918671,  66042.25475509,
#        167341.61095866,  62697.5217523 ,  64426.36551274, 150390.45550897,
#         71302.16459495,  89947.4177688 ,  41591.72192505,  62917.88117014,
#        141840.87776069,  85492.57744396,  94032.95960535,  97044.99442929,
#         69429.25026849, 127150.42375198,  55047.49503288,  63354.04788273,
#         58310.97693782,  46656.1911145 ,  73909.71679425,  85806.70197205,
#         46921.83757705,  66712.85892902,  92733.87660117,  61201.62569154,
#        163501.22515967,  59244.35279785,  66974.57884584,  58999.33206338,
#         52631.81743851,  68420.27522756,  64188.51255922,  79803.94534298,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df9.corr(), annot=True, cmap='viridis')
plt.show()

# %% [raw]
# 49. Food Delivery Time Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df10 = pd.read_csv(r'C:\Users\USER\Downloads\Sample_Submission.csv')

# %%
df10
# Out:
#             ID  Time_taken (min)
# 0      0x2318          25.668333
# 1      0x3474          27.881667
# 2      0x9420          27.023333
# 3      0x72ee          28.153333
# 4      0xa759          21.018333
# ...        ...               ...
# 11394  0x6909          21.972500
# 11395  0x443b          29.390000
# 11396  0x1ea5          26.244167
# 11397  0x22d4          23.752500
# 11398  0xb7be          23.827500
#
# [11399 rows x 2 columns]

# %%
df10.head()
# Out:
#         ID  Time_taken (min)
# 0  0x2318          25.668333
# 1  0x3474          27.881667
# 2  0x9420          27.023333
# 3  0x72ee          28.153333
# 4  0xa759          21.018333

# %%
df10.tail()
# Out:
#             ID  Time_taken (min)
# 11394  0x6909          21.972500
# 11395  0x443b          29.390000
# 11396  0x1ea5          26.244167
# 11397  0x22d4          23.752500
# 11398  0xb7be          23.827500

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11399 entries, 0 to 11398
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                11399 non-null  object
#  1   Time_taken (min)  11399 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 178.2+ KB

# %%
df10.describe()
# Out:
#        Time_taken (min)
# count      11399.000000
# mean          26.234647
# std            8.408526
# min           10.394167
# 25%           20.143333
# 50%           24.527500
# 75%           32.139583
# max           52.315833

# %%
df10.isnull().sum()
# Out:
# ID                  0
# Time_taken (min)    0
# dtype: int64

# %%
df10.columns
# Out:
# Index(['ID', 'Time_taken (min)'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df10['ID'] = le.fit_transform(df10['ID'])

# %%
x = df10[['Time_taken (min)']]
y = df10 ['ID']

# %%
x
# Out:
#        Time_taken (min)
# 0             25.668333
# 1             27.881667
# 2             27.023333
# 3             28.153333
# 4             21.018333
# ...                 ...
# 11394         21.972500
# 11395         29.390000
# 11396         26.244167
# 11397         23.752500
# 11398         23.827500
#
# [11399 rows x 1 columns]

# %%
y
# Out:
# 0        1005
# 1        1879
# 2        7053
# 3        5217
# 4        8096
#          ...
# 11394    4653
# 11395    2692
# 11396     773
# 11397     995
# 11398    8955
# Name: ID, Length: 11399, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#        Time_taken (min)
# 5062          15.992500
# 6211          23.889167
# 486           29.229167
# 4584          39.395833
# 7460          27.816667
# ...                 ...
# 11284         35.098333
# 5191          13.985833
# 5390          23.834167
# 860           38.615000
# 7270          35.230833
#
# [9119 rows x 1 columns]

# %%
x_test
# Out:
#       Time_taken (min)
# 1766         25.933333
# 2629         21.195000
# 304          19.948333
# 3247         26.664167
# 4509         34.658333
# ...                ...
# 9624         22.815000
# 8948         28.145000
# 2439         22.471667
# 6843         14.746667
# 1360         26.530833
#
# [2280 rows x 1 columns]

# %%
y_train
# Out:
# 5062       230
# 6211      2292
# 486       6901
# 4584      4405
# 7460      8313
#          ...
# 11284     8132
# 5191     10826
# 5390      5226
# 860       1147
# 7270      2278
# Name: ID, Length: 9119, dtype: int64

# %%
y_test
# Out:
# 1766      998
# 2629    10844
# 304      6215
# 3247     1975
# 4509     4487
#         ...
# 9624     7114
# 8948     5450
# 2439     1964
# 6843     1127
# 1360     7928
# Name: ID, Length: 2280, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([5674.13369729, 5692.18892118, 5696.93929314, ..., 5687.32423546,
#        5716.7600296 , 5671.85694817], shape=(2280,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df10.corr(), annot=True, cmap='viridis')
plt.show()

# %%
50. Student Performance Factors

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df11 = pd.read_csv(r'C:\Users\USER\Downloads\StudentPerformanceFactors.csv')

# %%
df11
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df11.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df11.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df11.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df11.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df11.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df11 ['Teacher_Quality'] = df11['Teacher_Quality'].ffill()
df11 ['Parental_Education_Level'] = df11['Parental_Education_Level'].ffill()
df11 ['Distance_from_Home'] = df11['Distance_from_Home'].ffill()

# %%
df11.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df11 = df11.drop(columns = ['Learning_Disabilities'])
df11 = df11.drop(columns = ['Peer_Influence'])
df11 = df11.drop(columns = ['Teacher_Quality'])
df11 = df11.drop(columns = ['Previous_Scores'])

# %%
df11
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours Motivation_Level Internet_Access  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns_to_encode = [
    'Extracurricular_Activities', 'Motivation_Level', 
    'Internet_Access', 'Parental_Education_Level', 'Distance_from_Home','Gender','Family_Income','School_Type','Parental_Involvement','Access_to_Resources'
]

for col in columns_to_encode:
    df11[col] = le.fit_transform(df11[col])

# %%
df11
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     1                    0
# 1                19          64                     1                    2
# 2                24          98                     2                    2
# 3                29          89                     1                    2
# 4                19          92                     2                    2
# ...             ...         ...                   ...                  ...
# 6602             25          69                     0                    2
# 6603             23          76                     0                    2
# 6604             20          90                     2                    1
# 6605             10          86                     0                    0
# 6606             15          67                     2                    1
#
#       Extracurricular_Activities  Sleep_Hours  Motivation_Level  \
# ...

# %%
x = df11.drop('Exam_Score', axis = 1)
y = df11['Exam_Score']

# %%
x
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     1                    0
# 1                19          64                     1                    2
# 2                24          98                     2                    2
# 3                29          89                     1                    2
# 4                19          92                     2                    2
# ...             ...         ...                   ...                  ...
# 6602             25          69                     0                    2
# 6603             23          76                     0                    2
# 6604             20          90                     2                    1
# 6605             10          86                     0                    0
# 6606             15          67                     2                    1
#
#       Extracurricular_Activities  Sleep_Hours  Motivation_Level  \
# ...

# %%
y
# Out:
# 0       67
# 1       61
# 2       74
# 3       71
# 4       70
#         ..
# 6602    68
# 6603    69
# 6604    68
# 6605    68
# 6606    64
# Name: Exam_Score, Length: 6607, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 5810             27          79                     1                    0
# 1268             16          86                     0                    2
# 414              22          87                     1                    2
# 4745             18         100                     0                    2
# 654              35          78                     0                    1
# ...             ...         ...                   ...                  ...
# 3772             15          82                     2                    2
# 5191             20          65                     2                    2
# 5226             17          64                     0                    1
# 5390             16         100                     0                    0
# 860              21          62                     2                    1
#
#       Extracurricular_Activities  Sleep_Hours  Motivation_Level  \
# ...

# %%
x_test
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 743              20          71                     2                    1
# 5551             22          71                     2                    1
# 3442             21          91                     0                    2
# 6571             12          91                     2                    1
# 4204             21          63                     1                    0
# ...             ...         ...                   ...                  ...
# 4709             20          78                     0                    2
# 3664             27          90                     0                    0
# 5231             23          72                     1                    2
# 1773             21          76                     1                    2
# 5782             23          87                     0                    2
#
#       Extracurricular_Activities  Sleep_Hours  Motivation_Level  \
# ...

# %%
y_train
# Out:
# 5810    69
# 1268    69
# 414     66
# 4745    72
# 654     72
#         ..
# 3772    66
# 5191    65
# 5226    62
# 5390    73
# 860     62
# Name: Exam_Score, Length: 5285, dtype: int64

# %%
y_test
# Out:
# 743     65
# 5551    65
# 3442    71
# 6571    64
# 4204    66
#         ..
# 4709    69
# 3664    72
# 5231    66
# 1773    63
# 5782    72
# Name: Exam_Score, Length: 1322, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
p = model.predict(x_test)

# %%
p
# Out:
# array([65.39844362, 66.07092172, 70.65783132, ..., 66.86513274,
#        66.82659355, 69.12833228], shape=(1322,))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df11.corr(), annot=True, cmap='viridis')
plt.show()
